# %%
import fastai

from fastai.vision import *

# %%
PATH  = '/home/agnext/Documents/tea_infer/'

# %%
# !ls $PATH
# Out:
# export.pkl  fast_infer.ipynb  tea.py

# %%
learn = load_learner(PATH,test=ImageList.from_folder('test'))

# %%
learn.summary
# Out:
# <bound method model_summary of Learner(data=ImageDataBunch;
#
# Train: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: /home/agnext/Documents/tea_infer;
#
# Valid: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: /home/agnext/Documents/tea_infer;
#
# Test: LabelList (0 items)
# x: ImageList
#
# y: EmptyLabelList
#
# Path: /home/agnext/Documents/tea_infer, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
img = open_image('/home/agnext/Documents/tea_infer/1.jpg')
img
# Out:
# Image (3, 639, 551)

# %%
pred_class,pred_idx,outputs =learn.predict(img)

# %%
pred_class
# Out:
# Category Normal

# %%
pred_idx
# Out:
# tensor(1)

# %%
outputs
# Out:
# tensor([0.0013, 0.9987])
